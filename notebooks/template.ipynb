# %% [markdown]
# <img width="8%" alt="Jupyter.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Jupyter.png" style="border-radius: 15%">

# %% [markdown]
# <div align="center">
# <h1 style="color:rgb(121, 65, 6);">Speech Emotion Recognition</h1>
# <a href="https://example.com/">Give Feedback</a> | <a href="https://example.com/">Bug report</a>
#
# </div>

# %% [markdown]
# **Tags:** #ser #audio #machinelearning

# %% [markdown]
# **Author:** [Ndeye Awa Salane](https://www.linkedin.com/in/ndeye-awa-salane-a93667230/)

# %% [markdown]
# **Last update:** 2025-04-13 (Created: 2025-04-13)

# %% [markdown]
# **Description:** desc

# %%
# pip install kagglehub

# %% [markdown]
# ### Import libraries

# %%
import kagglehub

# %% [markdown]
# ## Input

# %%
# Download latest version
path = kagglehub.dataset_download("uwrfkaggler/ravdess-emotional-speech-audio")


print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\dell\.cache\kagglehub\datasets\uwrfkaggler\ravdess-emotional-speech-audio\versions\1

# %% [markdown]
# ## Model

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %% [markdown]
# ## Table of Contents
# [1. Import Libraries](#import-libraries)
# [2. RAVDESS](#ravdess)
# [3. SAVEE](#savee)
# [4. TESS](#tess)
# [5. CREMA-D](#crema-d)
# [6. Conclusions](#cocnlcusions)

# %%
# # Generate a spectrogram
# spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sr)
# log_spectrogram = librosa.power_to_db(spectrogram)

# # Plot the spectrogram
# plt.figure(figsize=(10, 4))
# librosa.display.specshow(log_spectrogram, sr=sr, x_axis='time', y_axis='mel', cmap='coolwarm')
# plt.title("Mel Spectrogram")
# plt.colorbar(format='%+2.0f dB')
# plt.show()

# %%
# # Extract MFCCs from the audio file
# mfccs = librosa.feature.mfcc(y=audio_data, sr=sr, n_mfcc=13)

# # Plot MFCCs
# plt.figure(figsize=(10, 4))
# librosa.display.specshow(mfccs, sr=sr, x_axis='time', cmap='viridis')
# plt.title("MFCCs")
# plt.colorbar()
# plt.show()

# %%
mfccs.shape
# Out:
# (13, 101)
